# %%
#Analysis.....
By satistical data,American sleep more duing past 15 years,
In 2003 average sleep was 9 was as it reaches to 65 over but as such so the Income level; falls short.

# %%
#dependencies
import seaborn as sns
import pandas as pd

# %%
all_data = pd.read_csv("Resources/all_data_v3.csv")
all_data
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 0             0    2003  Annual                      8.48           0.031
# 1             1    2004  Annual                      8.48           0.040
# 2             2    2005  Annual                      8.53           0.034
# 3             3    2006  Annual                      8.56           0.035
# 4             4    2007  Annual                      8.52           0.038
# ..          ...     ...     ...                       ...             ...
# 265         265    2016  Annual                      8.97           0.054
# 266         266    2016  Annual                      8.97           0.054
# 267         267    2017  Annual                      8.91           0.072
# 268         268    2017  Annual                      8.91           0.072
# 269         269    2017  Annual                      8.91           0.072
#
#     Type of Days        Age Group_x  Activity Gender_x  \
# ...

# %%
all_data.columns
# Out:
# Index(['Unnamed: 0', 'Year_x', 'Period', 'Avg hrs per day sleeping',
#        'Standard Error', 'Type of Days', 'Age Group_x', 'Activity', 'Gender_x',
#        'Unique ID', 'Age Group_y', 'Year_y', 'Gender_y',
#        'Number with income (thousands)', 'Mean income', '2022\ndollars'],
#       dtype='object')

# %%
#all_data['Age Group_x']=pd.cut(all_data.,bins=[0,29,40,200],right=True,labels=['65 and over'])
#plt.figure(figsize=(10,8))
#sns.countplot(x='Age Group_x',data=all_data,hue='65 and over')
#plt.show()

# %%
df_65=all_data.loc[all_data["Age Group_x"] == "65 years and over"]
df_65
# Out:
#      Unnamed: 0  Year_x  Period  Avg hrs per day sleeping  Standard Error  \
# 90           90    2003  Annual                      8.89           0.066
# 91           91    2003  Annual                      8.89           0.066
# 92           92    2003  Annual                      8.89           0.066
# 93           93    2004  Annual                      8.76           0.067
# 94           94    2004  Annual                      8.76           0.067
# ..          ...     ...     ...                       ...             ...
# 265         265    2016  Annual                      8.97           0.054
# 266         266    2016  Annual                      8.97           0.054
# 267         267    2017  Annual                      8.91           0.072
# 268         268    2017  Annual                      8.91           0.072
# 269         269    2017  Annual                      8.91           0.072
#
#     Type of Days        Age Group_x  Activity Gender_x  \
# ...

# %%
sns.lmplot(x = "Avg hrs per day sleeping", y = "Mean income",hue = "Gender_x", data = df_65)
#Analysis:Here a regresition line is shown for both male,
female data for 2003-2017 mean incime to avg hr of sleep,
with increase in sleep so is the income at 65 to over years
in male but in female its not the case.The points close to regression shown ,
A regression line here almost flat not a favourable condition 
closer to x axis shown not  well deserved good relation as respect to other
age group to sleep,vs income. a straight line that describes how a response 
variable y changes as an explanatory variable x changes.

# %%
sns.lmplot(x = "Avg hrs per day sleeping", y = "Mean income",hue = "Gender_x", col="Gender_x",data = df_65)
#Analysis.....
here the scatterplot with regression line shows expectation
of both male a nd female response of mean income to avg  hr of sleep.
For make the relation is up more scatter then to female closer to x-axis.
In other words it shows how much in y variable is caused by x variable.

# %%
sns.lmplot(x = "Avg hrs per day sleeping", y = "Mean income",hue = "Year_x", col="Gender_x",palette = "Set2",
           markers=["o","s","+","x","*","o","s","+","x","*","o","s","+","x","*"],data = df_65)
#analysis is higher for male,
Here for male the income mean to sleep shows a
good correlation as compared to female.
The trend is not so strong,
sleep is more so is income,straight up its directly prop, 
but here its not ideal little increase,little income increase with avergae hr.

# %%
#2017 analysis
#Here income go up for gender_x,male,2013,2014 is same,in female its 2003,2004,same income sleep is more.
