# %% [markdown]
# Sleep and Income Correlation Analysis

# %%
#Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
#Read the sleep data set
sleep_data= pd.read_csv('all_data(1)')
sleep_data_df=pd.DataFrame(sleep_data)
sleep_data_df
# Out:
#      Year  Period  Avg hrs per day sleeping  Standard Error  \
# 0    2003  Annual                      8.57           0.018
# 1    2004  Annual                      8.55           0.026
# 2    2005  Annual                      8.62           0.023
# 3    2006  Annual                      8.63           0.024
# 4    2007  Annual                      8.57           0.024
# ..    ...     ...                       ...             ...
# 940  2013  Annual                      8.83           0.085
# 941  2014  Annual                      8.98           0.086
# 942  2015  Annual                      8.83           0.074
# 943  2016  Annual                      8.92           0.071
# 944  2017  Annual                      8.81           0.091
#
#             Type of Days          Age Group  Activity  Gender  \
# 0               All days  15 years and over  Sleeping    Both
# 1               All days  15 years and over  Sleeping    Both
# ...

# %%
#Read the income data set
income_data= pd.read_csv('Table P9 Clean.csv')
income_data_df=pd.DataFrame(income_data)
income_data_df
# Out:
#              Age Group  Year Gender Number with income (thousands)  \
# 0    15 years and over  2022   Male                         119400
# 1    15 years and over  2021   Male                         118200
# 2    15 years and over  2020   Male                         117900
# 3    15 years and over  2019   Male                         116600
# 4    15 years and over  2018   Male                         115200
# ..                 ...   ...    ...                            ...
# 945  75 Years and Over  1991   Male                          4,494
# 946  75 Years and Over  1990   Male                          4,352
# 947  75 Years and Over  1989   Male                          4,294
# 948  75 Years and Over  1988   Male                          4,182
# 949  75 Years and Over  1987   Male                          4,040
#
#     Mean income 2022\ndollars                    Unique ID
# 0         70340         70340  2022-15 years and over-Male
# ...

# %%
#Merge the datasets
all_data= pd.merge(sleep_data, income_data, on='Unique ID',how='inner')
all_data.to_csv("all_data.csv")
